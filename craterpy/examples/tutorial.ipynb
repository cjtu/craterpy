# %% [markdown]
# # craterpy - Crater Data Science in Python
#
# written by Christian Tai Udovicic (cj.taiudovicic@gmail.com)
#
# ## Housekeeping
#
# See [github.com/cjtu/craterpy](github.com/cjtu/craterpy) for the project homepage and installation instructions. Full API documentation is available at [readthedocs.org](readthedocs.org/projects/craterpy). Issues with or questions about this tutorial can be reported on the [issue tracker](https://github.com/cjtu/craterpy/issues).

# %% [markdown]
# ## Introduction
#
# **craterpy** is a data analysis library for importing, processing, analyzing images of impact craters. Use this library to:
#
# - Clipping crater regions of interest (ROIs) from image data
# - Extract crater interiors or ejecta blankets from ROIs
# - Run custom statistics on any or all regions of interest
# - Automate the above on many craters by supplying a DataFrame/table of craters
#
# This Tutorial will walk you through a basic craterpy workflow and highlight some features along the way. Check out [examples](https://github.com/cjtu/craterpy/tree/master/craterpy/examples) for other feature explanations and starter scripts.

# %%
# Prep this notebook (get path to example data)
import os.path as p
data_dir = p.join(p.dirname(p.abspath(".")), "data")
moon_tif = p.join(data_dir, "moon.tif")

# %% [markdown]
# ## craterpy.dataset.CraterpyDataset
#
# The easiest way to get started with craterpy is to import image data from a GeoTIFF file with the `CraterpyDataset`.
#
# **Warning**: craterpy currently only supports **simple cylindrical** a.k.a. **Plate Caree** a.k.a. **unprojected** image data. To use data in other projections, please reproject your data first (e.g. with `gdal`) and then import it with `craterpy`.

# %%
from craterpy.dataset import CraterpyDataset
moon = CraterpyDataset(moon_tif)
print(moon)
# Out:
# CraterpyDataset with extent (90.0N, -90.0N), (-180.0E, 180.0E), radius 6378.137 km, and resolution 4.0 ppd

# %% [markdown]
# Because `moon_tif` is a geotiff, its geographic information can be read automatically. For datasets without geotiff tags, or to override the automatic tags, specify *nlat*, *slat*, *wlon*, *elon*, *radius* (of the planetary body), and/or *ppd* (resolution in pix/degree):

# %%
moon = CraterpyDataset(moon_tif, nlat=90, slat=-90, wlon=-180,
                     elon=180, radius=1737, ppd=4)
print(moon)
# Out:
# CraterpyDataset with extent (90N, -90N), (-180E, 180E), radius 1737 km, and resolution 4 ppd

# %% [markdown]
# The `CraterpyDataset` wraps `gdal.Dataset`, meaning that all file formats supported by `gdal` are also supported by the `CraterpyDataset`. The `gdal.Dataset` attributes and methods are also available, e.g. `Dataset.ReadAsArray()`:

# %%
import matplotlib.pyplot as plt
moonarr = moon.ReadAsArray(0, 0, 1440, 720)  # This is a gdal.Dataset method
plt.imshow(moonarr, cmap="gray")
plt.show()

# %% [markdown]
# ## craterpy.roi.CraterRoi
#
# The CraterpyDataset is used in conjunction with the CraterRoi to extract regions of interest (ROIs) around craters. Here, we target the Orientale impact basin located at (19.4S, 92.8W) with radius 327 km.

# %%
from craterpy.roi import CraterRoi
orientaleRoi = CraterRoi(moon, -19.4, -92.8, 327)
print(orientaleRoi)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-065da545240e> in <module>()
#       1 from craterpy.roi import CraterRoi
# ----> 2 orientaleRoi = CraterRoi(moon, -19.4, -92.8, 327)
#       3 print(orientaleRoi)
#
# ~\AppData\Local\conda\conda\envs\craterpy\lib\site-packages\craterpy-0.2.2-py3.5.egg\craterpy\roi.py in __init__(self, cds, lat, lon, rad, wsize, plot)
#      55         self.wsize = wsize
#      56         self.extent = self._get_extent()
# ---> 57         self.roi = self._get_roi()
#      58         if plot:
#      59             self.plot()
#
# ~\AppData\Local\conda\conda\envs\craterpy\lib\site-packages\craterpy-0.2.2-py3.5.egg\craterpy\roi.py in _get_roi(self)
#     111             if self.lon > 180:
#     112                 self.lon -= 360
# --> 113             return self.cds.get_roi(*self.extent)
#     114
#     115     def filter(self, vmin=float('-inf'), vmax=float('inf'), strict=False,
#
# ~\AppData\Local\conda\conda\envs\craterpy\lib\site-packages\craterpy-0.2.2-py3.5.egg\craterpy\dataset.py in get_roi(self, minlon, maxlon, minlat, maxlat)
#     220         if not (self.inbounds(minlon, minlat) and
#     221                 self.inbounds(maxlat, maxlon)):
# --> 222             raise ImportError("Roi extent out of dataset bounds.")
#     223         topind = ch.deg2pix(self.nlat-maxlat, self.ppd)
#     224         height = ch.deg2pix(maxlat-minlat, self.ppd)
#
# ImportError: Roi extent out of dataset bounds.

# %% [markdown]
# The wsize parameter will scale the ROI. The ROI extends out `wsize*radius` from the crater center (by default `wsize=1`).

# %%
orientaleROI = moonADS.get_roi(-19.4, -92.8, 327, wsize=2)
plt.imshow(orientaleROI, cmap="gray")
plt.show()

# %% [markdown]
# The `plot_roi` parameter is a shortcut to plot the roi to the shell and the `mask_crater` parameter automatically applies a mask of NaN to the interior of the crater (this will be useful later in the tutorial).

# %%
orientaleROI = moonADS.get_roi(-19.4, -92.8, 327, wsize=2, 
                            plot_roi=True, mask_crater=True)

# %% [markdown]
# The AceDataset.get_roi() method returns data as a numpy 2D array.

# %%
type(orientaleROI)
# Out:
# numpy.ndarray

# %%
orientaleROI.shape
# Out:
# (182, 182)

# %%
np.nanmean(orientaleROI)
# Out:
# 73.588141736943328

# %% [markdown]
# ROIs which extend beyond the bounds of the `AceDataset` will raise an `OutOfBoundsException`, unless the AceDataset is global and the ROI only crosses the longitude extent. In this case the `get_roi()` method will wrap around to return the desired data.

# %%
try:
    moonADS.get_roi(90, 0, 100, plot_roi=True)
except ValueError as e:
    print(e)
# Out:
# Latitude or longitude out of bounds.

# %%
wraped_lon_boundary = moonADS.get_roi(0, 180, 1000, plot_roi=True)

# %% [markdown]
# The `AceDataset` and its `get_roi()` method can be used as is to query image data in python, but most ACERIM functions will also require a `CraterDataFrame`.

# %% [markdown]
# ## CraterDataFrame

# %% [markdown]
# The `CraterDataFrame` extends the `pandas.DataFrame` object. All `DataFrame` methods and attributes are available to the `CraterDataFrame` (see [pandas](https://pandas.pydata.org/pandas-docs/stable/) for documentation and info).

# %%
# Import craters from csv located at same data_dir as above
from acerim.aceclasses import CraterDataFrame
moonCDF = CraterDataFrame(data_dir+"/craters.csv")  
moonCDF.head()
# Out:
#              Name     Rad    Lat     Lon
# 0        Olbers D  50.015  10.23  -78.03
# 1        Schuster  50.040   4.44  146.42
# 2         Gilbert  50.125  -3.20   76.16
# 3          Cabeus  50.290 -85.33  -42.13
# 4  Kovalevskaya Q  50.315  29.18 -131.44

# %% [markdown]
# The `CraterDataFrame` requires at least 3 columns of tabular data, the *latitude*, *longitude*, and *radius* of craters in the table. One strength of the `CraterDataFrame` object is that it automatically scans the header row for these three columns and saves a reference to them in the attributes latcol, loncol, and radcol, respectively. This avoids issues with inconsistent naming conventions.

# %%
print(moonCDF.latcol, moonCDF.loncol, moonCDF.radcol)
# Out:
# Lat Lon Rad

# %% [markdown]
# If the columns cannot be located automatically or to manually override them, specify the names of the respective columns as parameters:

# %%
moonCDF = CraterDataFrame(data_dir+"/craters.csv", latcol="Lat", loncol="Lon",
                          radcol="Rad")
print(moonCDF.latcol, moonCDF.loncol, moonCDF.radcol)
# Out:
# Lat Lon Rad

# %% [markdown]
# The `radcol` parameter is important because ACERIM assumes that crater size data is given as a radius. If it does not find a radius column, `CraterDataFrame` will search for a diameter column instead and automatically generate the "radius" column as shown below.

# %%
moonCDF = CraterDataFrame(data_dir+"/craters_no_rad.csv")
moonCDF.head()
# Out:
#              Name    Diam    Lat     Lon  radius
# 0        Olbers D  100.03  10.23  -78.03  50.015
# 1        Schuster  100.08   4.44  146.42  50.040
# 2         Gilbert  100.25  -3.20   76.16  50.125
# 3          Cabeus  100.58 -85.33  -42.13  50.290
# 4  Kovalevskaya Q  100.63  29.18 -131.44  50.315

# %% [markdown]
# This way, when accessing a `CraterDataFrame` by attribute, we can be certain that the correct column of data is read.

# %%
moonCDF.head()[moonCDF.radcol]
# Out:
# 0    50.015
# 1    50.040
# 2    50.125
# 3    50.290
# 4    50.315
# Name: radius, dtype: float64

# %% [markdown]
# The `index_col` parameter can be set to index the `CraterDataFrame` to the ID column, in this case the *Name* column at index 0:

# %%
moonCDF = CraterDataFrame(data_dir+"/craters.csv", index_col=0)
moonCDF.head()
# Out:
#                    Rad    Lat     Lon
# Name
# Olbers D        50.015  10.23  -78.03
# Schuster        50.040   4.44  146.42
# Gilbert         50.125  -3.20   76.16
# Cabeus          50.290 -85.33  -42.13
# Kovalevskaya Q  50.315  29.18 -131.44

# %% [markdown]
# Now craters can be queried by their names using the `.loc[]` pandas DataFrame syntax:

# %%
moonCDF.loc['Schuster']
# Out:
# Rad     50.04
# Lat      4.44
# Lon    146.42
# Name: Schuster, dtype: float64

# %% [markdown]
# All typical `DataFrame` syntax can be used on the `CratreDataFrame`:

# %%
moonCDF.head()[moonCDF.radcol]
# Out:
# Name
# Olbers D          50.015
# Schuster          50.040
# Gilbert           50.125
# Cabeus            50.290
# Kovalevskaya Q    50.315
# Name: Rad, dtype: float64

# %%
moonCDF.at['Schuster', 'Lat']
# Out:
# 4.4400000000000004

# %% [markdown]
# `CraterDataFrames` can also be filtered using "fancy" (boolean) indexing:

# %%
moonCDF_gt150 = moonCDF[moonCDF[moonCDF.radcol] > 150] 
moonCDF_gt150.head()
# Out:
#                           Rad    Lat     Lon
# Name
# Bailly                150.280 -66.82  -68.90
# Sikorsky-Rittenhouse  155.000 -68.00  111.00
# Schrodinger           158.195 -74.73  132.93
# Planck                159.730 -57.27  135.34
# Mendeleev             162.565   5.38  141.17

# %%
moonCDF_20N20S = moonCDF[(moonCDF['Lat'] >= -20) & (moonCDF['Lat'] <= 20)]
moonCDF_20N20S.head()
# Out:
#              Rad    Lat     Lon
# Name
# Olbers D  50.015  10.23  -78.03
# Schuster  50.040   4.44  146.42
# Gilbert   50.125  -3.20   76.16
# Ventris   50.370  -4.77  157.97
# Fridman   50.725 -12.48 -126.88

# %% [markdown]
# ## Acefunctions

# %% [markdown]
# With a functioning `AceDataset` and `CraterDataframe`, all of functions from `acefunctions.py` can now be used. For example, statistics can be quickly calculated on crater ejecta blankets and returned as tabular data:

# %%
from acerim import acefunctions as af
#statCDF = af.ejecta_stats(moonCDF_20N20S[:5], moonADS, plot=True)
#statCDF.head()

# %% [markdown]
# **TODO**: here we will explain how the various parts of acefunctions work
